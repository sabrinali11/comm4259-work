# %% [markdown]
# **Hi! My name is Sabrina Li**
# - Pronounced Sah-brina Lee

# %% [markdown]
# I am originally from Staten Island, NY and am studying Commerce (Management, IT, Analytics & AI) at UVA!
# - My hobbies are pottery, yoga, and solo-travel (just recently went to Spain & Italy in May 2026!)

# %% [markdown]
# ## Sabrina's Travel Destinations
# <mark>From my favorite places: Spain, Italy, Hong Kong, Singapore</mark>

# %% [markdown]
# # 🌍 Places I've Traveled
#
# ## Italy
# <img src="https://upload.wikimedia.org/wikipedia/commons/5/53/Colosseum_in_Rome%2C_Italy_-_April_2007.jpg" width="500">
#
# ## Spain
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d3/Zagrada_familia.jpg" width="500">
#
# ## Hong Kong
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/90/Victoria_Harbour_%28Hong_Kong%29.jpg" width="500">
#
# ## Singapore
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/00/Marina_Bay_Sands_Singapore_2026_1.jpg" width="500">

# %%
name = input("What is your name? ")

print("Nice to meet you, " + name + "!")

# %%
hobby = input("What is one of your hobbies? ")

print("That's cool! I also enjoy learning about people's hobbies.")
print(name + "'s hobby is " + hobby + ".")

# %% [markdown]
# **Thank you!!!**
